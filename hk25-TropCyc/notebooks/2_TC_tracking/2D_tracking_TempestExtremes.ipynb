# %% [markdown]
# # TC tracking with UZ algorithm and TempestExtremes software
# By Stella Bourdin

# %%
# Tracking parameters
run=arp-gem-1p3km
zoom=8

# Define files and dirs
## Connectivity file for the zoom level
CONNECT_FILE=/home/users/sbourdin/WCRP_Hackathon/hk25-teams/hk25-TropCyc/ConnectivityFiles/ConnectivityFiles_for_healpix_zoom_$zoom.txt
## Scratch with data
scr_dir=/work/scratch-nopw2/sbourdin/
data_dir=$scr_dir/$run/data_healpix/
flist=`ls $data_dir`
## Where to store nodes
nodes_dir=$scr_dir/$run/nodes
if ! [ -d $nodes_dir ]; then mkdir $nodes_dir; fi
## Where to store tracks
tracks_dir="tracks/"
if ! [ -d $tracks_dir ]; then mkdir $tracks_dir; fi

# %%
## Running DetectNodes over each month
echo `date`

for f in $flist
do

    echo ----- ${f::-3} -----
    IN_FILE=$data_dir/$f
    OUT_FILE=$nodes_dir/${f::-3}.dat
    
    if ! [ -f $OUT_FILE ]; then
        conda run -n hackathon DetectNodes \
        --in_data $IN_FILE \
        --out $OUT_FILE \
        --searchbymin "psl" \
        --mergedist 6.0 \
        --closedcontourcmd "psl,200.0,5.5,0" \
        --outputcmd "psl,min,0;_VECMAG(uas,vas),max,2;orog,min,0" \
        --in_connect $CONNECT_FILE
    else 
    echo "Nodes already computed"
    fi

done

echo `date`
# Out:
# Tue May 20 15:08:44 UTC 2025
# ----- 2020-01 -----
# Arguments:
#   --in_data <string> ["/work/scratch-nopw2/sbourdin//arp-gem-1p3km/data_healpix//2020-01.nc"]
#   --in_data_list <string> [""]
#   --in_connect <string> ["/home/users/sbourdin/WCRP_Hackathon/hk25-teams/hk25-TropCyc/ConnectivityFiles/ConnectivityFiles_for_healpix_zoom_8.txt"]
#   --diag_connect <bool> [false]
#   --out <string> ["/work/scratch-nopw2/sbourdin//arp-gem-1p3km/nodes/2020-01.dat"]
#   --out_file_list <string> [""]
#   --searchbymin <string> ["psl"] (default PSL)
#   --searchbymax <string> [""]
#   --searchbythreshold <string> [""]
#   --minlon <double> [0.000000] (degrees)
#   --maxlon <double> [0.000000] (degrees)
#   --minlat <double> [0.000000] (degrees)
#   --maxlat <double> [0.000000] (degrees)
#   --minabslat <double> [0.000000] (degrees)
#   --mergedist <double> [6.000000] (degrees)
#   --mergeequal <bool> [false]
#   --closedcontourcmd <string> ["psl,200.0,5.5,0"] [var,delta,dist,minmaxdist;...]
#   --noclosedcontourcmd <string> [""] [var,delta,dist,minmaxdist;...]
#   --thresholdcmd <string> [""] [var,op,value,dist;...]
#   --outputcmd <string> ["psl,min,0;_VECMAG(uas,vas),max,2;orog,min,0"] [var,op,dist;...]
#   --timestride <integer> [1]
#   --timefilter <string> [""]
#   --latname <string> ["lat"]
#   --lonname <string> ["lon"]
#   --regional <bool> [false]
#   --out_header <bool> [false]
#   --out_seconds <bool> [false]
#   --logdir <string> ["."]
#   --verbosity <integer> [0]
# ------------------------------------------------------------
# Parsing closed contour operations
# ..psl increases by 200.000000 over 5.500000 degrees (min search 0.000000 deg)
# ..Done
# Parsing output operations
# ..Minimum of psl within 0.000000 degrees
# ..Maximum of _VECMAG(uas,vas) within 2.000000 degrees
# ..Minimum of orog within 0.000000 degrees
# ..Done
# Begin search operation
# ..Loading grid data from connectivity file.. Done
# ..Time 2020-01-01 06:00:00
# ....Total candidates: 36
# ....Rejected (  location): 0
# ....Rejected (    merged): 87214
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 50
# ....Done
# ..Time 2020-01-01 12:00:00
# ....Total candidates: 36
# ....Rejected (  location): 0
# ....Rejected (    merged): 87162
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 48
# ....Done
# ..Time 2020-01-01 18:00:00
# ....Total candidates: 48
# ....Rejected (  location): 0
# ....Rejected (    merged): 86991
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 43
# ....Done
# ..Time 2020-01-02 00:00:00
# ....Total candidates: 41
# ....Rejected (  location): 0
# ....Rejected (    merged): 86815
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 38
# ....Done
# ..Time 2020-01-02 06:00:00
# ....Total candidates: 43
# ....Rejected (  location): 0
# ....Rejected (    merged): 86064
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 54
# ....Done
# ..Time 2020-01-02 12:00:00
# ....Total candidates: 42
# ....Rejected (  location): 0
# ....Rejected (    merged): 85009
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 46
# ....Done
# ..Time 2020-01-02 18:00:00
# ....Total candidates: 51
# ....Rejected (  location): 0
# ....Rejected (    merged): 85330
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 38
# ....Done
# ..Time 2020-01-03 00:00:00
# ....Total candidates: 43
# ....Rejected (  location): 0
# ....Rejected (    merged): 85095
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 36
# ....Done
# ..Time 2020-01-03 06:00:00
# ....Total candidates: 46
# ....Rejected (  location): 0
# ....Rejected (    merged): 85487
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 27
# ....Done
# ..Time 2020-01-03 12:00:00
# ....Total candidates: 43
# ....Rejected (  location): 0
# ....Rejected (    merged): 86072
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 46
# ....Done
# ..Time 2020-01-03 18:00:00
# ....Total candidates: 45
# ....Rejected (  location): 0
# ....Rejected (    merged): 86297
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 26
# ....Done
# ..Time 2020-01-04 00:00:00
# ....Total candidates: 53
# ....Rejected (  location): 0
# ....Rejected (    merged): 85830
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 40
# ....Done
# ..Time 2020-01-04 06:00:00
# ....Total candidates: 48
# ....Rejected (  location): 0
# ....Rejected (    merged): 86326
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 32
# ....Done
# ..Time 2020-01-04 12:00:00
# ....Total candidates: 41
# ....Rejected (  location): 0
# ....Rejected (    merged): 86260
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 47
# ....Done
# ..Time 2020-01-04 18:00:00
# ....Total candidates: 49
# ....Rejected (  location): 0
# ....Rejected (    merged): 86197
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 35
# ....Done
# ..Time 2020-01-05 00:00:00
# ....Total candidates: 57
# ....Rejected (  location): 0
# ....Rejected (    merged): 86425
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 33
# ....Done
# ..Time 2020-01-05 06:00:00
# ....Total candidates: 46
# ....Rejected (  location): 0
# ....Rejected (    merged): 86789
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 30
# ....Done
# ..Time 2020-01-05 12:00:00
# ....Total candidates: 44
# ....Rejected (  location): 0
# ....Rejected (    merged): 86780
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 38
# ....Done
# ..Time 2020-01-05 18:00:00
# ....Total candidates: 45
# ....Rejected (  location): 0
# ....Rejected (    merged): 86981
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 39
# ....Done
# ..Time 2020-01-06 00:00:00
# ....Total candidates: 44
# ....Rejected (  location): 0
# ....Rejected (    merged): 86554
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 39
# ....Done
# ..Time 2020-01-06 06:00:00
# ....Total candidates: 38
# ....Rejected (  location): 0
# ....Rejected (    merged): 86724
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 34
# ....Done
# ..Time 2020-01-06 12:00:00
# ....Total candidates: 48
# ....Rejected (  location): 0
# ....Rejected (    merged): 86827
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 44
# ....Done
# ..Time 2020-01-06 18:00:00
# ....Total candidates: 51
# ....Rejected (  location): 0
# ....Rejected (    merged): 86778
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 36
# ....Done
# ..Time 2020-01-07 00:00:00
# ....Total candidates: 45
# ....Rejected (  location): 0
# ....Rejected (    merged): 86098
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 36
# ....Done
# ..Time 2020-01-07 06:00:00
# ....Total candidates: 44
# ....Rejected (  location): 0
# ....Rejected (    merged): 86018
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 38
# ....Done
# ..Time 2020-01-07 12:00:00
# ....Total candidates: 55
# ....Rejected (  location): 0
# ....Rejected (    merged): 85858
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 44
# ....Done
# ..Time 2020-01-07 18:00:00
# ....Total candidates: 48
# ....Rejected (  location): 0
# ....Rejected (    merged): 86533
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 36
# ....Done
# ..Time 2020-01-08 00:00:00
# ....Total candidates: 48
# ....Rejected (  location): 0
# ....Rejected (    merged): 86582
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 43
# ....Done
# ..Time 2020-01-08 06:00:00
# ....Total candidates: 47
# ....Rejected (  location): 0
# ....Rejected (    merged): 86214
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 47
# ....Done
# ..Time 2020-01-08 12:00:00
# ....Total candidates: 34
# ....Rejected (  location): 0
# ....Rejected (    merged): 85921
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 59
# ....Done
# ..Time 2020-01-08 18:00:00
# ....Total candidates: 39
# ....Rejected (  location): 0
# ....Rejected (    merged): 85780
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 45
# ....Done
# ..Time 2020-01-09 00:00:00
# ....Total candidates: 44
# ....Rejected (  location): 0
# ....Rejected (    merged): 85505
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 43
# ....Done
# ..Time 2020-01-09 06:00:00
# ....Total candidates: 44
# ....Rejected (  location): 0
# ....Rejected (    merged): 86510
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 40
# ....Done
# ..Time 2020-01-09 12:00:00
# ....Total candidates: 40
# ....Rejected (  location): 0
# ....Rejected (    merged): 86457
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 48
# ....Done
# ..Time 2020-01-09 18:00:00
# ....Total candidates: 41
# ....Rejected (  location): 0
# ....Rejected (    merged): 86894
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 45
# ....Done
# ..Time 2020-01-10 00:00:00
# ....Total candidates: 41
# ....Rejected (  location): 0
# ....Rejected (    merged): 86834
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 42
# ....Done
# ..Time 2020-01-10 06:00:00
# ....Total candidates: 43
# ....Rejected (  location): 0
# ....Rejected (    merged): 86415
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 30
# ....Done
# ..Time 2020-01-10 12:00:00
# ....Total candidates: 35
# ....Rejected (  location): 0
# ....Rejected (    merged): 86443
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 47
# ....Done
# ..Time 2020-01-10 18:00:00
# ....Total candidates: 41
# ....Rejected (  location): 0
# ....Rejected (    merged): 85760
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 42
# ....Done
# ..Time 2020-01-11 00:00:00
# ....Total candidates: 40
# ....Rejected (  location): 0
# ....Rejected (    merged): 86049
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 47
# ....Done
# ..Time 2020
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 45
# ....Done
# ..Time 2020-01-23 18:00:00
# ....Total candidates: 47
# ....Rejected (  location): 0
# ....Rejected (    merged): 85795
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 58
# ....Done
# ..Time 2020-01-24 00:00:00
# ....Total candidates: 41
# ....Rejected (  location): 0
# ....Rejected (    merged): 86033
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 41
# ....Done
# ..Time 2020-01-24 06:00:00
# ....Total candidates: 42
# ....Rejected (  location): 0
# ....Rejected (    merged): 86143
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 44
# ....Done
# ..Time 2020-01-24 12:00:00
# ....Total candidates: 38
# ....Rejected (  location): 0
# ....Rejected (    merged): 86194
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 51
# ....Done
# ..Time 2020-01-24 18:00:00
# ....Total candidates: 42
# ....Rejected (  location): 0
# ....Rejected (    merged): 85816
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 39
# ....Done
# ..Time 2020-01-25 00:00:00
# ....Total candidates: 35
# ....Rejected (  location): 0
# ....Rejected (    merged): 84767
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 48
# ....Done
# ..Time 2020-01-25 06:00:00
# ....Total candidates: 41
# ....Rejected (  location): 0
# ....Rejected (    merged): 84865
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 45
# ....Done
# ..Time 2020-01-25 12:00:00
# ....Total candidates: 44
# ....Rejected (  location): 0
# ....Rejected (    merged): 85370
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 37
# ....Done
# ..Time 2020-01-25 18:00:00
# ....Total candidates: 44
# ....Rejected (  location): 0
# ....Rejected (    merged): 85417
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 58
# ....Done
# ..Time 2020-01-26 00:00:00
# ....Total candidates: 47
# ....Rejected (  location): 0
# ....Rejected (    merged): 86141
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 37
# ....Done
# ..Time 2020-01-26 06:00:00
# ....Total candidates: 45
# ....Rejected (  location): 0
# ....Rejected (    merged): 86390
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 40
# ....Done
# ..Time 2020-01-26 12:00:00
# ....Total candidates: 53
# ....Rejected (  location): 0
# ....Rejected (    merged): 87298
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 34
# ....Done
# ..Time 2020-01-26 18:00:00
# ....Total candidates: 63
# ....Rejected (  location): 0
# ....Rejected (    merged): 86559
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 42
# ....Done
# ..Time 2020-01-27 00:00:00
# ....Total candidates: 53
# ....Rejected (  location): 0
# ....Rejected (    merged): 87297
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 31
# ....Done
# ..Time 2020-01-27 06:00:00
# ....Total candidates: 48
# ....Rejected (  location): 0
# ....Rejected (    merged): 87638
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 35
# ....Done
# ..Time 2020-01-27 12:00:00
# ....Total candidates: 47
# ....Rejected (  location): 0
# ....Rejected (    merged): 87954
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 34
# ....Done
# ..Time 2020-01-27 18:00:00
# ....Total candidates: 45
# ....Rejected (  location): 0
# ....Rejected (    merged): 87983
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 40
# ....Done
# ..Time 2020-01-28 00:00:00
# ....Total candidates: 45
# ....Rejected (  location): 0
# ....Rejected (    merged): 88017
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 33
# ....Done
# ..Time 2020-01-28 06:00:00
# ....Total candidates: 43
# ....Rejected (  location): 0
# ....Rejected (    merged): 87938
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 26
# ....Done
# ..Time 2020-01-28 12:00:00
# ....Total candidates: 41
# ....Rejected (  location): 0
# ....Rejected (    merged): 87386
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 30
# ....Done
# ..Time 2020-01-28 18:00:00
# ....Total candidates: 37
# ....Rejected (  location): 0
# ....Rejected (    merged): 87319
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 41
# ....Done
# ..Time 2020-01-29 00:00:00
# ....Total candidates: 37
# ....Rejected (  location): 0
# ....Rejected (    merged): 87462
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 40
# ....Done
# ..Time 2020-01-29 06:00:00
# ....Total candidates: 42
# ....Rejected (  location): 0
# ....Rejected (    merged): 86888
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 38
# ....Done
# ..Time 2020-01-29 12:00:00
# ....Total candidates: 48
# ....Rejected (  location): 0
# ....Rejected (    merged): 86715
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 38
# ....Done
# ..Time 2020-01-29 18:00:00
# ....Total candidates: 47
# ....Rejected (  location): 0
# ....Rejected (    merged): 86166
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 31
# ....Done
# ..Time 2020-01-30 00:00:00
# ....Total candidates: 49
# ....Rejected (  location): 0
# ....Rejected (    merged): 86158
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 32
# ....Done
# ..Time 2020-01-30 06:00:00
# ....Total candidates: 42
# ....Rejected (  location): 0
# ....Rejected (    merged): 86002
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 50
# ....Done
# ..Time 2020-01-30 12:00:00
# ....Total candidates: 41
# ....Rejected (  location): 0
# ....Rejected (    merged): 85819
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 43
# ....Done
# ..Time 2020-01-30 18:00:00
# ....Total candidates: 47
# ....Rejected (  location): 0
# ....Rejected (    merged): 86194
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 35
# ....Done
# ..Time 2020-01-31 00:00:00
# ....Total candidates: 41
# ....Rejected (  location): 0
# ....Rejected (    merged): 86428
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 30
# ....Done
# ..Time 2020-01-31 06:00:00
# ....Total candidates: 46
# ....Rejected (  location): 0
# ....Rejected (    merged): 86336
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 39
# ....Done
# ..Time 2020-01-31 12:00:00
# ....Total candidates: 46
# ....Rejected (  location): 0
# ....Rejected (    merged): 86231
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 47
# ....Done
# ..Time 2020-01-31 18:00:00
# ....Total candidates: 50
# ....Rejected (  location): 0
# ....Rejected (    merged): 85019
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 39
# ....Done
# ..Done
# ------------------------------------------------------------
#
# ----- 2020-02 -----
# Arguments:
#   --in_data <string> ["/work/scratch-nopw2/sbourdin//arp-gem-1p3km/data_healpix//2020-02.nc"]
#   --in_data_list <string> [""]
#   --in_connect <string> ["/home/users/sbourdin/WCRP_Hackathon/hk25-teams/hk25-TropCyc/ConnectivityFiles/ConnectivityFiles_for_healpix_zoom_8.txt"]
#   --diag_connect <bool> [false]
#   --out <string> ["/work/scratch-nopw2/sbourdin//arp-gem-1p3km/nodes/2020-02.dat"]
#   --out_file_list <string> [""]
#   --searchbymin <string> ["psl"] (default PSL)
#   --searchbymax <string> [""]
#   --searchbythreshold <string> [""]
#   --minlon <double> [0.000000] (degrees)
#   --maxlon <double> [0.000000] (degrees)
#   --minlat <double> [0.000000] (degrees)
#   --maxlat <double> [0.000000] (degrees)
#   --minabslat <double> [0.000000] (degrees)
#   --mergedist <double> [6.000000] (degrees)
#   --mergeequal <bool> [false]
#   --closedcontourcmd <string> ["psl,200.0,5.5,0"] [var,delta,dist,minmaxdist;...]
#   --noclosedcontourcmd <string> [""] [var,delta,dist,minmaxdist;...]
#   --thresholdcmd <string> [""] [var,op,value,dist;...]
#   --outputcmd <string> ["psl,min,0;_VECMAG(uas,vas),max,2;orog,min,0"] [var,op,dist;...]
#   --timestride <integer> [1]
#   --timefilter <string> [""]
#   --latname <string> ["lat"]
#   --lonname <string> ["lon"]
#   --regional <bool> [false]
#   --out_header <bool> [false]
#   --out_seconds <bool> [false]
#   --logdir <string> ["."]
#   --verbosity <integer> [0]
# ------------------------------------------------------------
# Parsing closed contour operations
# ..psl increases by 200.000000 over 5.500000 degrees (min search 0.000000 deg)
# ..Done
# Parsing output operations
# ..Minimum of psl within 0.000000 degrees
# ..Maximum of _VECMAG(uas,vas) within 2.000000 degrees
# ..Minimum of orog within 0.000000 degrees
# ..Done
# Begin search operation
# ..Loading grid data from connectivity file.. Done
# ..Time 2020-02-01 00:00:00
# ....Total candidates: 45
# ....Rejected (  location): 0
# ....Rejected (    merged): 85086
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 28
# ....Done
# ..Time 2020-02-01 06:00:00
# ....Total candidates: 43
# ....Rejected (  location): 0
# ....Rejected (    merged): 85617
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 31
# ....Done
# ..Time 2020-02-01 12:00:00
# ....Total candidates: 49
# ....Rejected (  location): 0
# ....Rejected (    merged): 86059
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 29
# ....Done
# ..Time 2020-02-01 18:00:00
# ....Total candidates: 49
# ....Rejected (  location): 0
# ....Rejected (    merged): 86338
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 41
# ....Done
# ..Time 2020-02-02 00:00:00
# ....Total candidates: 40
# ....Rejected (  location): 0
# ....Rejected (    merged): 86718
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 39
# ....Done
# ..Time 2020-02-02 06:00:00
# ....Total candidates: 39
# ....Rejected (  location): 0
# ....Rejected (    merged): 86358
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 41
# ....Done
# ..Time 2020-02-02 12:00:00
# ....Total candidates: 41
# ....Rejected (  location): 0
# ....Rejected (    merged): 86134
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 38
# ....Done
# ..Time 2020-02-02 18:00:00
# ....Total candidates: 47
# ....Rejected (  location): 0
# ....Rejected (    merged): 87220
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 41
# ....Done
# ..Time 2020-02-03 00:00:00
# ....Total candidates: 51
# ....Rejected (  location): 0
# ....Rejected (    merged): 87108
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 34
# ....Done
# ..Time 2020-02-03 06:00:00
# ....Total candidates: 49
# ....Rejected (  location): 0
# ....Rejected (    merged): 87738
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 34
# ....Done
# ..Time 2020-02-03 12:00:00
# ....Total candidates: 44
# ....Rejected (  location): 0
# ....Rejected (    merged): 88356
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 43
# ....Done
# ..Time 2020-02-03 18:00:00
# ....Total candidates: 47
# ....Rejected (  location): 0
# ....Rejected (    merged): 88838
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 42
# ....Done
# ..Time 2020-02-04 00:00:00
# ....Total candidates: 46
# ....Rejected (  location): 0
# ....Rejected (    merged): 88131
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 38
# ....Done
# ..Time 2020-02-04 06:00:00
# ....Total candidates: 49
# ....Rejected (  location): 0
# ....Rejected (    merged): 87999
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 50
# ....Done
# ..Time 2020-02-04 12:00:00
# ....Total candidates: 49
# ....Rejected (  location): 0
# ....Rejected (    merged): 87808
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 32
# ....Done
# ..Time 2020-02-04 18:00:00
# ....Total candidates: 44
# ....Rejected (  location): 0
# ....Rejected (    merged): 87656
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 36
# ....Done
# ..Time 2020-02-05 00:00:00
# ....Total candidates: 46
# ....Rejected (  location): 0
# ....Rejected (    merged): 87587
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 40
# ....Done
# ..Time 2020-02-05 06:00:00
# ....Total candidates: 39
# ....Rejected (  location): 0
# ....Rejected (    merged): 87602
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 47
# ....Done
# ..Time 2020-02-05 12:00:00
# ....Total candidates: 49
# ....Rejected (  location): 0
# ....Rejected (    merged): 88007
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 51
# ....Done
# ..Time 2020-02-05 18:00:00
# ....Total candidates: 51
# ....Rejected (  location): 0
# ....Rejected (    merged): 89250
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 45
# ....Done
# ..Time 2020-02-06 00:00:00
# ....Total candidates: 49
# ....Rejected (  location): 0
# ....Rejected (    merged): 88605
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 38
# ....Done
# ..Time 2020-02-06 06:00:00
# ....Total candidates: 37
# ....Rejected (  location): 0
# ....Rejected (    merged): 88455
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 54
# ....Done
# ..Time 2020-02-06 12:00:00
# ....Total candidates: 41
# ....Rejected (  location): 0
# ....Rejected (    merged): 88304
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 45
# ....Done
# ..Time 2020-02-06 18:00:00
# ....Total candidates: 49
# ....Rejected (  location): 0
# ....Rejected (    merged): 87366
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 47
# ....Done
# ..Time 2020-02-07 00:00:00
# ....Total candidates: 53
# ....Rejected (  location): 0
# ....Rejected (    merged): 87427
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 35
# ....Done
# ..Time 2020-02-07 06:00:00
# ....Total candidates: 45
# ....Rejected (  location): 0
# ....Rejected (    merged): 87256
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 39
# ....Done
# ..Time 2020-02-07 12:00:00
# ....Total candidates: 36
# ....Rejected (  location): 0
# ....Rejected (    merged): 87292
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 49
# ....Done
# ..Time 2020-02-07 18:00:00
# ....Total candidates: 43
# ....Rejected (  location): 0
# ....Rejected (    merged): 86735
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 43
# ....Done
# ..Time 2020-02-08 00:00:00
# ....Total candidates: 40
# ....Rejected (  location): 0
# ....Rejected (    merged): 86606
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 44
# ....Done
# ..Time 2020-02-08 06:00:00
# ....Total candidates: 39
# ....Rejected (  location): 0
# ....Rejected (    merged): 87151
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 47
# ....Done
# ..Time 2020-02-08 12:00:00
# ....Total candidates: 43
# ....Rejected (  location): 0
# ....Rejected (    merged): 87033
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 43
# ....Done
# ..Time 2020-02-08 18:00:00
# ....Total candidates: 47
# ....Rejected (  location): 0
# ....Rejected (    merged): 87532
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 38
# ....Done
# ..Time 2020-02-09 00:00:00
# ....Total candidates: 43
# ....Rejected (  location): 0
# ....Rejected (    merged): 87956
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 39
# ....Done
# ..Time 2020-02-09 06:00:00
# ....Total candidates: 46
# ....Rejected (  location): 0
# ....Rejected (    merged): 88100
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 39
# ....Done
# ..Time 2020-02-09 12:00:00
# ....Total candidates: 39
# ....Rejected (  location): 0
# ....Rejected (    merged):
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 50
# ....Done
# ..Time 2020-03-30 00:00:00
# ....Total candidates: 39
# ....Rejected (  location): 0
# ....Rejected (    merged): 89015
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 51
# ....Done
# ..Time 2020-03-30 06:00:00
# ....Total candidates: 48
# ....Rejected (  location): 0
# ....Rejected (    merged): 88944
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 42
# ....Done
# ..Time 2020-03-30 12:00:00
# ....Total candidates: 57
# ....Rejected (  location): 0
# ....Rejected (    merged): 88945
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 50
# ....Done
# ..Time 2020-03-30 18:00:00
# ....Total candidates: 52
# ....Rejected (  location): 0
# ....Rejected (    merged): 89993
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 49
# ....Done
# ..Time 2020-03-31 00:00:00
# ....Total candidates: 48
# ....Rejected (  location): 0
# ....Rejected (    merged): 89693
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 33
# ....Done
# ..Time 2020-03-31 06:00:00
# ....Total candidates: 49
# ....Rejected (  location): 0
# ....Rejected (    merged): 89376
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 45
# ....Done
# ..Time 2020-03-31 12:00:00
# ....Total candidates: 50
# ....Rejected (  location): 0
# ....Rejected (    merged): 89214
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 48
# ....Done
# ..Time 2020-03-31 18:00:00
# ....Total candidates: 62
# ....Rejected (  location): 0
# ....Rejected (    merged): 88871
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 40
# ....Done
# ..Done
# ------------------------------------------------------------
#
# ----- 2020-04 -----
# Arguments:
#   --in_data <string> ["/work/scratch-nopw2/sbourdin//arp-gem-1p3km/data_healpix//2020-04.nc"]
#   --in_data_list <string> [""]
#   --in_connect <string> ["/home/users/sbourdin/WCRP_Hackathon/hk25-teams/hk25-TropCyc/ConnectivityFiles/ConnectivityFiles_for_healpix_zoom_8.txt"]
#   --diag_connect <bool> [false]
#   --out <string> ["/work/scratch-nopw2/sbourdin//arp-gem-1p3km/nodes/2020-04.dat"]
#   --out_file_list <string> [""]
#   --searchbymin <string> ["psl"] (default PSL)
#   --searchbymax <string> [""]
#   --searchbythreshold <string> [""]
#   --minlon <double> [0.000000] (degrees)
#   --maxlon <double> [0.000000] (degrees)
#   --minlat <double> [0.000000] (degrees)
#   --maxlat <double> [0.000000] (degrees)
#   --minabslat <double> [0.000000] (degrees)
#   --mergedist <double> [6.000000] (degrees)
#   --mergeequal <bool> [false]
#   --closedcontourcmd <string> ["psl,200.0,5.5,0"] [var,delta,dist,minmaxdist;...]
#   --noclosedcontourcmd <string> [""] [var,delta,dist,minmaxdist;...]
#   --thresholdcmd <string> [""] [var,op,value,dist;...]
#   --outputcmd <string> ["psl,min,0;_VECMAG(uas,vas),max,2;orog,min,0"] [var,op,dist;...]
#   --timestride <integer> [1]
#   --timefilter <string> [""]
#   --latname <string> ["lat"]
#   --lonname <string> ["lon"]
#   --regional <bool> [false]
#   --out_header <bool> [false]
#   --out_seconds <bool> [false]
#   --logdir <string> ["."]
#   --verbosity <integer> [0]
# ------------------------------------------------------------
# Parsing closed contour operations
# ..psl increases by 200.000000 over 5.500000 degrees (min search 0.000000 deg)
# ..Done
# Parsing output operations
# ..Minimum of psl within 0.000000 degrees
# ..Maximum of _VECMAG(uas,vas) within 2.000000 degrees
# ..Minimum of orog within 0.000000 degrees
# ..Done
# Begin search operation
# ..Loading grid data from connectivity file.. Done
# ..Time 2020-04-01 00:00:00
# ....Total candidates: 47
# ....Rejected (  location): 0
# ....Rejected (    merged): 88867
# ....Rejected ( threshold): 0
# ....Rejected (contour psl): 49
# ....Done
# ..Done
# ------------------------------------------------------------
#
# Tue May 20 15:17:32 UTC 2025

# %%
## Prepare list of nodesfiles
flist=`ls $nodes_dir/*`
cat $flist > $nodes_dir/all_nodes.dat

## StitchNodes
conda run -n hackathon StitchNodes \
--in $nodes_dir/all_nodes.dat \
--in_connect $CONNECT_FILE \
--out $tracks_dir/$run.csv \
--out_file_format "csv" \
--in_fmt "lon,lat,slp,wind,orog" \
--range 8.0 \
--mintime "54h" \
--maxgap "24h" \
--threshold "wind,>=,10.0,10;lat,<=,45.0,10;lat,>=,-45.0,10;lat,<=,25,1;lat,>=,-25,1;orog,<=,150.0,10" 
# NB: Double-check that the output does not mention gaps in the data
# Check that the period covered is the one you expect

rm $nodes_dir/all_nodes.dat
# Out:
# Arguments:
#   --in <string> ["/work/scratch-nopw2/sbourdin//arp-gem-1p3km/nodes/all_nodes.dat"]
#   --in_list <string> [""]
#   --in_connect <string> ["/home/users/sbourdin/WCRP_Hackathon/hk25-teams/hk25-TropCyc/ConnectivityFiles/ConnectivityFiles_for_healpix_zoom_8.txt"]
#   --out <string> ["tracks//arp-gem-1p3km.csv"]
#   --in_fmt <string> ["lon,lat,slp,wind,orog"]
#   --range <double> [8.000000] (degrees)
#   --mintime <string> ["54h"]
#   --time_begin <string> [""]
#   --time_end <string> [""]
#   --prioritize <string> [""]
#   --min_endpoint_dist <double> [0.000000] (degrees)
#   --min_path_dist <double> [0.000000] (degrees)
#   --maxgap <string> ["24h"]
#   --threshold <string> ["wind,>=,10.0,10;lat,<=,45.0,10;lat,>=,-45.0,10;lat,<=,25,1;lat,>=,-25,1;orog,<=,150.0,10"] [col,op,value,count;...]
#   --caltype <string> ["standard"] (none|standard|noleap|360_day)
#   --allow_repeated_times <bool> [false]
#   --add_velocity <bool> [false]
#   --out_file_format <string> ["csv"] (gfdl|csv|csvnohead)
#   --out_seconds <bool> [false]
# ------------------------------------------------------------
# Parsing thresholds
# ..wind greater than or equal to 10.000000 at least 10 time(s)
# ..lat less than or equal to 45.000000 at least 10 time(s)
# ..lat greater than or equal to -45.000000 at least 10 time(s)
# ..lat less than or equal to 25.000000 at least 1 time(s)
# ..lat greater than or equal to -25.000000 at least 1 time(s)
# ..orog less than or equal to 150.000000 at least 10 time(s)
# ..Done
# Loading candidate data
# ..Discrete times: 364 (2020-01-01 06:00:00 to 2020-04-01 00:00:00)
# ..Done
# Creating KD trees at each time level.. Done
# Constructing paths
# ..Populating set of path segments.. Done
# ..Connecting path segments.. Done
# ..Done
# Filtering paths
# ..Paths rejected (mintime): 2802
# ..Paths rejected (minendpointdist): 0
# ..Paths rejected (minpathdist): 0
# ..Paths rejected (threshold): 444
# ..Total paths found: 48
# ..Done
# Writing results.. Done
# Cleanup.. Done
# ------------------------------------------------------------
